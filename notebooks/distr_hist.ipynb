# %%
import pandas as pd
import scipy.stats
import matplotlib.pyplot as plt
import numpy as np
thesis_dir = '/home/azstephe/liverRegression/regression_liver/data/thesis_plots/'

colors = {
        'Rat': '#94c4be',      
        'Macaque': '#89a1b6',
        'Cow': '#d1c177',      
        'Pig': '#d59698',
        'Mouse': '#a3a3a3',
}
def histogram(pred_df, name, status):
    species = status.split(' ')[-1]
    plt.hist(pred_df, bins=50, color=colors[species])
    plt.xlim(0,4.1)
    plt.xlabel(f'{name}')
    plt.ylabel('Count')
    plt.title(f'Histogram of {status}')
    # plt.savefig(f"{thesis_dir}{direc}{status.replace(' ', '_')}.png", dpi=300, bbox_inches='tight')
    plt.show()

# %%
# histograms of raw data (signal strength)
direc = 'raw_hist/'
df = pd.read_csv('/home/azstephe/liverRegression/regression_liver/data/raw/mouse_liver_pos_ALL.narrowPeak', header=None, sep = '\t')
histogram(df[6], 'Signal Strength', 'Raw Mouse')

df = pd.read_csv('/home/azstephe/liverRegression/regression_liver/data/raw/macaque_liver_pos_ALL.narrowPeak', header=None, sep = '\t')
histogram(df[6], 'Signal Strength', 'Raw Macaque')

df = pd.read_csv('/home/azstephe/liverRegression/regression_liver/data/raw/rat_liver_pos_ALL.narrowPeak', header=None, sep = '\t')
histogram(df[6], 'Signal Strength', 'Raw Rat')

df = pd.read_csv('/home/azstephe/liverRegression/regression_liver/data/raw/cow_liver_pos_ALL_chromName.narrowPeak', header=None, sep = '\t')
histogram(df[6], 'Signal Strength', 'Raw Cow')

df = pd.read_csv('/home/azstephe/liverRegression/regression_liver/data/raw/pig_liver_pos_ALL.narrowPeak', header=None, sep = '\t')
histogram(df[6], 'Signal Strength', 'Raw Pig')

df = pd.read_csv('/home/azstephe/liverRegression/regression_liver/data/log_same_size/pig_liver_pos_ALL.bed', header=None, sep = '\t')
histogram(df[4], 'Signal Strength', 'raw pig')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 19
#      16 histogram(df[6], 'Signal Strength', 'Raw Pig')
#      18 df = pd.read_csv('/home/azstephe/liverRegression/regression_liver/data/log_same_size/pig_liver_pos_ALL.bed', header=None, sep = '\t')
# ---> 19 histogram(df[4], 'Signal Strength', 'raw pig')
#
# Cell In[19], line 16, in histogram(pred_df, name, status)
#      14 def histogram(pred_df, name, status):
#      15     species = status.split(' ')[-1]
# ---> 16     plt.hist(pred_df, bins=50, color=colors[species])
#      17     plt.xlim(0,60)
#      18     plt.xlabel(f'{name}')
#
# KeyError: 'pig'

# %%
# histograms of logged data
direc = 'log_hist/'
df = pd.read_csv('/home/azstephe/liverRegression/regression_liver/data/log/mouse_liver_pos_ALL.bed', header=None, sep = '\t')
histogram(df[4], 'Signal Strength', 'Logged Mouse')

df = pd.read_csv('/home/azstephe/liverRegression/regression_liver/data/log/macaque_liver_pos_ALL.bed', header=None, sep = '\t')
histogram(df[4], 'Signal Strength', 'Logged Macaque')

df = pd.read_csv('/home/azstephe/liverRegression/regression_liver/data/log/rat_liver_pos_ALL.bed', header=None, sep = '\t')
histogram(df[4], 'Signal Strength', 'Logged Rat')

df = pd.read_csv('/home/azstephe/liverRegression/regression_liver/data/log/cow_liver_pos_ALL.bed', header=None, sep = '\t')
histogram(df[4], 'Signal Strength', 'Logged Cow')

df = pd.read_csv('/home/azstephe/liverRegression/regression_liver/data/log/pig_liver_pos_ALL.bed', header=None, sep = '\t')
histogram(df[4], 'Signal Strength', 'Logged Pig')

# %%
# histogram of logged overlay all 5 species
import pandas as pd
import matplotlib.pyplot as plt
direc = 'log_hist/'
# Define file paths and labels
files = {
    'Mouse': '/home/azstephe/liverRegression/regression_liver/data/log/mouse_liver_pos_ALL.bed',
    'Macaque': '/home/azstephe/liverRegression/regression_liver/data/log/macaque_liver_pos_ALL.bed',
    'Rat': '/home/azstephe/liverRegression/regression_liver/data/log/rat_liver_pos_ALL.bed',
    'Cow': '/home/azstephe/liverRegression/regression_liver/data/log/cow_liver_pos_ALL.bed',
    'Pig': '/home/azstephe/liverRegression/regression_liver/data/log/pig_liver_pos_ALL.bed'
}

# Define species colors (adjust if needed)
colors = {
    'Mouse': '#74899b',
    'Macaque': '#89a1b6',
    'Rat': '#94c4be',
    'Cow': '#d59698',
    'Pig': '#d1c177'
}

# Plot all histograms on the same figure
plt.figure(figsize=(6, 4.8))

for species, path in files.items():
    df = pd.read_csv(path, header=None, sep='\t')
    plt.hist(df[4], bins=50, alpha=0.6, label=species, color=colors[species], density=True)

plt.xlabel('Signal Strength')
plt.ylabel('Density')
plt.title('Logged ATAC-seq Signal Distribution')
plt.legend(title="Species")
plt.tight_layout()
plt.savefig(f"{thesis_dir}{direc}all5_overlay.png", dpi=300, bbox_inches='tight')
plt.show()

# %%
# histograms of logged, random 20615 data
df = pd.read_csv('/home/azstephe/liverRegression/regression_liver/data/log_same_size/mouse_liver_pos_ALL.bed', header=None, sep = '\t')
histogram(df[4], 'signal strength', '20615 random logged mouse')
df = pd.read_csv('/home/azstephe/liverRegression/regression_liver/data/log_same_size/macaque_liver_pos_ALL.bed', header=None, sep = '\t')
histogram(df[4], 'signal strength', '20615 random logged macaque')
df = pd.read_csv('/home/azstephe/liverRegression/regression_liver/data/log_same_size/rat_liver_pos_ALL.bed', header=None, sep = '\t')
histogram(df[4], 'signal strength', '20615 random logged rat')
df = pd.read_csv('/home/azstephe/liverRegression/regression_liver/data/log_same_size/cow_liver_pos_ALL_chromName.bed', header=None, sep = '\t')
histogram(df[4], 'signal strength', '20615 random logged cow')
df = pd.read_csv('/home/azstephe/liverRegression/regression_liver/data/log_same_size/pig_liver_pos_ALL.bed', header=None, sep = '\t')
histogram(df[4], 'signal strength', '20615 random logged pig')

# %%
rat_val2 = '/home/azstephe/liverRegression/regression_liver/data/splits/val2/macaque_liver_VAL.narrowPeak'
rat_val3 = '/home/azstephe/liverRegression/regression_liver/data/splits/val3/macaque_liver_VAL.narrowPeak'
df = pd.read_csv(rat_val2, header=None, sep = '\t')
histogram(df[4], 'signal strength', 'macaque val2')
df = pd.read_csv(rat_val3, header=None, sep = '\t')
histogram(df[4], 'signal strength', 'macaque val3')

# %%
rat_val2 = '/home/azstephe/liverRegression/regression_liver/data/splits/ladderPos/mouse_liver_VAL.narrowPeak'
rat_val3 = '/home/azstephe/liverRegression/regression_liver/data/splits/ladderPos/mouse_liver_TRAINONLY.narrowPeak'
df = pd.read_csv(rat_val2, header=None, sep = '\t')
histogram(df[4], 'signal strength', 'mouse val')
df = pd.read_csv(rat_val3, header=None, sep = '\t')
histogram(df[4], 'signal strength', 'mouse train')

# %%
# histograms of raw LCL data
df = pd.read_csv('/home/azstephe/immunetacit/genomes/human/idr.optimal_peak_enhancershort.narrowPeak', header=None, sep = '\t')
histogram(df[6], 'signal strength', 'raw human LCL')

df = pd.read_csv('/projects/pfenninggroup/machineLearningForComputationalBiology/regElEvoGrant/MouseDNase/CH12LX/peak/idr_reproducibility/idr.optimal_enhancerShort_peak.narrowPeak.gz', compression='gzip', header=None, sep = '\t')
histogram(df[6], 'signal strength', 'raw mouse CH12LX')

df = pd.read_csv('/projects/pfenninggroup/machineLearningForComputationalBiology/regElEvoGrant/MacaqueAtac/LCL/peak/idr_reproducibility/idr.optimal_enhancerShort_peak.narrowPeak.gz', compression='gzip', header=None, sep = '\t')
histogram(df[6], 'signal strength', 'raw macaque LCL')

df = pd.read_csv('/home/azstephe/immunetacit/genomes/pongo/pooled-pr1_vs_pooled-pr2.idr0.05.bfilt_enhancerShort.narrowPeak', header=None, sep = '\t')
histogram(df[6], 'signal strength', 'raw orangutan LCL')

df = pd.read_csv('/home/azstephe/immunetacit/genomes/gorilla/idr.optimal_peak_notEnhancershort_chromName.narrowPeak', header=None, sep = '\t')
histogram(df[6], 'signal strength', 'raw gorilla LCL')

df = pd.read_csv('/projects/pfenninggroup/machineLearningForComputationalBiology/regElEvoGrant/ChimpAtac/LCL/peak/rep2-pseudorep1_vs_2/rep2-pr1_vs_rep2-pr2.idr0.05.bfilt_enhancerShort.narrowPeak', header=None, sep = '\t')
histogram(df[6], 'signal strength', 'raw chimp LCL')

# %%
# histograms of logged LCL data
df = pd.read_csv('/home/azstephe/immunetacit/repos/lcl_cnn/data/log/humanLCL_pos_ALL.bed', header=None, sep = '\t')
histogram(df[4], 'signal strength', 'logged human LCL')

df = pd.read_csv('/home/azstephe/immunetacit/repos/lcl_cnn/data/log/mouseCH12LX_pos_ALL.bed', header=None, sep = '\t')
histogram(df[4], 'signal strength', 'logged mouse CH12LX')

df = pd.read_csv('/home/azstephe/immunetacit/repos/lcl_cnn/data/log/macaqueLCL_pos_ALL.bed', header=None, sep = '\t')
histogram(df[4], 'signal strength', 'logged macaque LCL')

df = pd.read_csv('/home/azstephe/immunetacit/repos/lcl_cnn/data/log/orangutanLCL_pos_ALL.bed', header=None, sep = '\t')
histogram(df[4], 'signal strength', 'logged orangutan LCL')

df = pd.read_csv('/home/azstephe/immunetacit/repos/lcl_cnn/data/log/gorillaLCL_pos_ALL.bed', header=None, sep = '\t')
histogram(df[4], 'signal strength', 'logged gorilla LCL')

df = pd.read_csv('/home/azstephe/immunetacit/repos/lcl_cnn/data/log/chimpanzeeLCL_pos_ALL.bed', header=None, sep = '\t')
histogram(df[4], 'signal strength', 'logged chimpanzee LCL')

# %%
# histograms of QN logged LCL data
df = pd.read_csv('/home/azstephe/immunetacit/repos/lcl_cnn/data/random_log_10525/quantile_norm/humanLCL_pos_ALL.bed', header=None, sep = '\t')
histogram(df[4], 'signal strength', 'QN log human LCL')

df = pd.read_csv('/home/azstephe/immunetacit/repos/lcl_cnn/data/random_log_10525/quantile_norm/mouseCH12LX_pos_ALL.bed', header=None, sep = '\t')
histogram(df[4], 'signal strength', 'QN log mouse CH12LX')

df = pd.read_csv('/home/azstephe/immunetacit/repos/lcl_cnn/data/random_log_10525/quantile_norm/macaqueLCL_pos_ALL.bed', header=None, sep = '\t')
histogram(df[4], 'signal strength', 'QN log macaque LCL')

df = pd.read_csv('/home/azstephe/immunetacit/repos/lcl_cnn/data/random_log_10525/quantile_norm/orangutanLCL_pos_ALL.bed', header=None, sep = '\t')
histogram(df[4], 'signal strength', 'QN log orangutan LCL')

df = pd.read_csv('/home/azstephe/immunetacit/repos/lcl_cnn/data/random_log_10525/quantile_norm/gorillaLCL_pos_ALL.bed', header=None, sep = '\t')
histogram(df[4], 'signal strength', 'QN log gorilla LCL')

df = pd.read_csv('/home/azstephe/immunetacit/repos/lcl_cnn/data/random_log_10525/quantile_norm/chimpanzeeLCL_pos_ALL.bed', header=None, sep = '\t')
histogram(df[4], 'signal strength', 'QN log chimpanzee LCL')

# %%
direc = 'ladder_qn_hist'
df = pd.read_csv('/home/azstephe/liverRegression/regression_liver/data/ladder_qn/mouse_liver_pos_ALL.bed', header=None, sep = '\t')
histogram(df[4], 'Signal Strength', 'Ladder QN Mouse')
df = pd.read_csv('/home/azstephe/liverRegression/regression_liver/data/ladder_qn/macaque_liver_pos_ALL.bed', header=None, sep = '\t')
histogram(df[4], 'Signal Strength', 'Ladder QN Macaque')
df = pd.read_csv('/home/azstephe/liverRegression/regression_liver/data/ladder_qn/rat_liver_pos_ALL.bed', header=None, sep = '\t')
histogram(df[4], 'Signal Strength', 'Ladder QN Rat')
df = pd.read_csv('/home/azstephe/liverRegression/regression_liver/data/ladder_qn/cow_liver_pos_ALL.bed', header=None, sep = '\t')
histogram(df[4], 'Signal Strength', 'Ladder QN Cow')
df = pd.read_csv('/home/azstephe/liverRegression/regression_liver/data/ladder_qn/pig_liver_pos_ALL.bed', header=None, sep = '\t')
histogram(df[4], 'Signal Strength', 'Ladder QN Pig')

# %%
# histogram of ladder_qn overlay all 5 species
import pandas as pd
import matplotlib.pyplot as plt
direc = 'ladder_qn_hist/'
# Define file paths and labels
files = {
    'Mouse': '/home/azstephe/liverRegression/regression_liver/data/ladder_qn/mouse_liver_pos_ALL.bed',
    'Macaque': '/home/azstephe/liverRegression/regression_liver/data/ladder_qn/macaque_liver_pos_ALL.bed',
    'Rat': '/home/azstephe/liverRegression/regression_liver/data/ladder_qn/rat_liver_pos_ALL.bed',
    'Cow': '/home/azstephe/liverRegression/regression_liver/data/ladder_qn/cow_liver_pos_ALL.bed',
    'Pig': '/home/azstephe/liverRegression/regression_liver/data/ladder_qn/pig_liver_pos_ALL.bed'
}

# Define species colors (adjust if needed)
colors = {
    'Mouse': '#74899b',
    'Macaque': '#89a1b6',
    'Rat': '#94c4be',
    'Cow': '#d59698',
    'Pig': '#d1c177'
}

# Plot all histograms on the same figure
plt.figure(figsize=(6, 4.8))

for species, path in files.items():
    df = pd.read_csv(path, header=None, sep='\t')
    plt.hist(df[4], bins=50, alpha=0.6, label=species, color=colors[species], density=True)

plt.xlabel('Signal Strength')
plt.ylabel('Density')
plt.title('Ladder QN ATAC-seq Signal Distribution')
plt.legend(title="Species")
plt.tight_layout()
plt.savefig(f"{thesis_dir}{direc}all5_overlay.png", dpi=300, bbox_inches='tight')
plt.show()

# %%
direc = 'random_qn_hist/'
df = pd.read_csv('/home/azstephe/liverRegression/regression_liver/data/quantile_norm/mouse_liver_pos_ALL.bed', header=None, sep = '\t')
histogram(df[4], 'Signal Strength', 'Random QN')

# %%
direc = 'largest_qn_hist/'
df = pd.read_csv('/home/azstephe/liverRegression/regression_liver/data/sorted_log_20615/quantile_norm/mouse_liver_pos_ALL.bed', header=None, sep = '\t')
histogram(df[4], 'Signal Strength', 'Largest QN')

# %%
# histogram of logged overlay all 5 species
import pandas as pd
import matplotlib.pyplot as plt
direc = 'raw_hist/'
# Define file paths and labels
files = {
    'Mouse': '/home/azstephe/liverRegression/regression_liver/data/raw/mouse_liver_pos_ALL.narrowPeak',
    'Macaque': '/home/azstephe/liverRegression/regression_liver/data/raw/macaque_liver_pos_ALL.narrowPeak',
    'Rat': '/home/azstephe/liverRegression/regression_liver/data/raw/rat_liver_pos_ALL.narrowPeak',
    'Cow': '/home/azstephe/liverRegression/regression_liver/data/raw/cow_liver_pos_ALL_chromName.narrowPeak',
    'Pig': '/home/azstephe/liverRegression/regression_liver/data/raw/pig_liver_pos_ALL.narrowPeak'
}

# Define species colors (adjust if needed)
colors = {
    'Mouse': '#74899b',
    'Macaque': '#89a1b6',
    'Rat': '#94c4be',
    'Cow': '#d59698',
    'Pig': '#d1c177'
}

# Plot all histograms on the same figure
# plt.figure(figsize=(6, 4.8))

for species, path in files.items():
    df = pd.read_csv(path, header=None, sep='\t')
    plt.hist(df[6], bins=50, alpha=0.6, label=species, color=colors[species])
plt.xlim(0,60)
plt.xlabel('Signal Strength')
plt.ylabel('Count')
plt.title('Raw ATAC-seq Signal Distribution')
plt.legend(title="Species")
plt.tight_layout()
plt.savefig(f"{thesis_dir}{direc}all5_overlay.png", dpi=300, bbox_inches='tight')
plt.show()

# %%
# histograms of logged test set
# direc = 'log_hist/'
df = pd.read_csv('/home/azstephe/liverRegression/regression_liver/data/test_splits/log_pos/mouse_liver_TEST_500bp.bed', header=None, sep = '\t')
histogram(df[4], 'Signal Strength', 'Logged Mouse')

df = pd.read_csv('/home/azstephe/liverRegression/regression_liver/data/test_splits/log_pos/macaque_liver_TEST_500bp.bed', header=None, sep = '\t')
histogram(df[4], 'Signal Strength', 'Logged Macaque')

df = pd.read_csv('/home/azstephe/liverRegression/regression_liver/data/test_splits/log_pos/rat_liver_TEST_500bp.bed', header=None, sep = '\t')
histogram(df[4], 'Signal Strength', 'Logged Rat')

df = pd.read_csv('/home/azstephe/liverRegression/regression_liver/data/test_splits/log_pos/cow_liver_TEST_500bp.bed', header=None, sep = '\t')
histogram(df[4], 'Signal Strength', 'Logged Cow')

df = pd.read_csv('/home/azstephe/liverRegression/regression_liver/data/test_splits/log_pos/pig_liver_TEST_500bp.bed', header=None, sep = '\t')
histogram(df[4], 'Signal Strength', 'Logged Pig')

# %%
# histogram of logged TEST overlay all 5 species
import pandas as pd
import matplotlib.pyplot as plt
# direc = 'log_hist/'
# Define file paths and labels
files = {
    'Mouse': '/home/azstephe/liverRegression/regression_liver/data/test_splits/log_pos/mouse_liver_TEST_500bp.bed',
    'Macaque': '/home/azstephe/liverRegression/regression_liver/data/test_splits/log_pos/macaque_liver_TEST_500bp.bed',
    'Rat': '/home/azstephe/liverRegression/regression_liver/data/test_splits/log_pos/rat_liver_TEST_500bp.bed',
    'Cow': '/home/azstephe/liverRegression/regression_liver/data/test_splits/log_pos/cow_liver_TEST_500bp.bed',
    'Pig': '/home/azstephe/liverRegression/regression_liver/data/test_splits/log_pos/pig_liver_TEST_500bp.bed'
}

# Define species colors (adjust if needed)
colors = {
    'Mouse': '#74899b',
    'Macaque': '#89a1b6',
    'Rat': '#94c4be',
    'Cow': '#d1c177',
    'Pig': '#d59698'
}

# Plot all histograms on the same figure
plt.figure(figsize=(6, 4.8))

for species, path in files.items():
    df = pd.read_csv(path, header=None, sep='\t')
    plt.hist(df[4], bins=50, alpha=0.6, label=species, color=colors[species], density=True)

plt.xlabel('Signal Strength')
plt.ylabel('Density')
plt.title('Logged ATAC-seq Test Set Signal Distribution')
plt.legend(title="Species")
plt.tight_layout()
# plt.savefig(f"{thesis_dir}{direc}all5_overlay.png", dpi=300, bbox_inches='tight')
plt.show()

# %%
pos_df = pd.read_csv(f'/home/azstephe/liverRegression/regression_liver/data/test_splits/log_pos/mouse_liver_TEST_500bp.bed', header=None, delim_whitespace=True).iloc[:,4]
pred_df = pd.read_csv(f'/home/azstephe/liverRegression/regression_liver/data/model_outputs/bdbi7l3n/activations_mouse_TEST.csv', header=None)
histogram(pred_df, 'mouse', 'Mouse')

# %%
df = pd.read_csv('/home/azstephe/liverRegression/regression_liver/data/test_splits/log_irene_wrong_test2/cow_liver_TEST_500bp_sorted.bed', header=None, sep = '\t')
histogram(df[4], 'Signal Strength', 'log irene wrong test2')

df2 = pd.read_csv('/home/azstephe/liverRegression/regression_liver/data/test_splits/log_remade_test2/cow_liver_TEST_500bp_sorted.bed', header=None, sep = '\t')
histogram(df2[4], 'Signal Strength', 'log remade test2')
# Out:
#          0         1         2          3         4
# 0    chr16  73229166  73229666  peak16974  1.277539
# 1     chr9  10424367  10424867   peak9750  1.356701
# 2    chr14  38904799  38905299  peak15179  1.380769
# 3    chr11   8859940   8860440  peak11818  1.382555
# 4    chr16  81272294  81272794  peak17100  1.526104
# ..     ...       ...       ...        ...       ...
# 235  chr16  63952292  63952792  peak16863  3.461932
# 236   chr3   3669085   3669585   peak2614  3.498323
# 237   chr2  19851256  19851756   peak1579  3.545307
# 238  chr10  37023527  37024027  peak11137  3.605511
# 239  chr14  36040966  36041466  peak15144  3.692050
#
# [240 rows x 5 columns]

# %%
def wilcoxon(neg, pos):
    stat, p_value = scipy.stats.ranksums(neg, pos)
    print("Wilcoxon Rank-Sum Test:")
    print(f"Test Statistic: {stat}")
    print(f"P-value: {p_value}")
    
    # Interpretation
    alpha = 0.05
    if p_value < alpha:
        print("There is a significant difference between the two distributions (reject null hypothesis).")
    else:
        print("There is no significant difference between the two distributions (fail to reject null hypothesis).")

wilcoxon(df[4], df2[4])
# Out:
# Wilcoxon Rank-Sum Test:
# Test Statistic: -0.6842278087670393
# P-value: 0.49383132468881363
# There is no significant difference between the two distributions (fail to reject null hypothesis).

# %%
df = pd.read_csv('/home/azstephe/liverRegression/regression_liver/data/splits/cow_pig/cow_pig_liver_pos_mouse_macaque_rat_closed_VAL_chromName_500bp.bed', header=None, sep = '\t')
histogram(df[4], 'Signal Strength', 'Val_Pig Cow')

# %%
df = pd.read_csv('/home/azstephe/liverRegression/regression_liver/data/test_splits/log_test4/cow_pig_liver_pos_TEST_500bp.bed', header=None, sep = '\t')
histogram(df[4], 'Signal Strength', 'Test_Pig Cow')

# %%
df = pd.read_csv('/home/azstephe/liverRegression/regression_liver/data/splits/cow_pig/cow_pig_liver_pos_mouse_macaque_rat_closed_TRAIN_chromName_500bp.bed', header=None, sep = '\t')
histogram(df[4], 'Signal Strength', 'Cow')

# %%
df = pd.read_csv('/home/azstephe/liverRegression/regression_liver/data/train_splits/cow_liver_TRAIN_500bp.bed', header=None, sep = '\t')
histogram(df[4], 'Signal Strength', 'Train Cow')

# %%
df = pd.read_csv('/home/azstephe/liverRegression/regression_liver/data/train_splits/pig_liver_TRAIN_500bp.bed', header=None, sep = '\t')
histogram(df[4], 'Signal Strength', 'Train Pig')
