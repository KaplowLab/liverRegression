# %%
import os
import tensorflow as tf

assert tf.config.list_physical_devices('GPU'), 'Start the colab kernel with GPU: Runtime -> Change runtime type -> GPU'

# 1. Force growth at the OS level (most robust for clusters)
os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'true'

# 2. Configure growth in the Python API
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        print(f"Successfully enabled memory growth on {len(gpus)} GPU(s)")
    except RuntimeError as e:
        # This catches the error if the kernel wasn't restarted
        print(f"Note: {e}")

# Verify visibility
print("Visible Devices:", tf.config.get_visible_devices())
# Out:
# 2026-01-06 18:18:59.212753: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# Successfully enabled memory growth on 1 GPU(s)
# Visible Devices: [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'), PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# 2026-01-06 18:19:01.328952: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcuda.so.1
# 2026-01-06 18:19:01.338663: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:3b:00.0 name: NVIDIA RTX A6000 computeCapability: 8.6
# coreClock: 1.8GHz coreCount: 84 deviceMemorySize: 47.54GiB deviceMemoryBandwidth: 715.34GiB/s
# 2026-01-06 18:19:01.338696: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2026-01-06 18:19:01.344545: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublas.so.11
# 2026-01-06 18:19:01.344593: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublasLt.so.11
# 2026-01-06 18:19:01.346110: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcufft.so.10
# 2026-01-06 18:19:01.347443: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcurand.so.10
# 2026-01-06 18:19:01.349215: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusolver.so.11
# 2026-01-06 18:19:01.350448: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusparse.so.11
# 2026-01-06 18:19:01.350953: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudnn.so.8
# 2026-01-06 18:19:01.351351: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0

# %%
# !pip install kipoiseq==0.5.2 --quiet > /dev/null
# You can ignore the pyYAML error

# %%
import tensorflow_hub as hub
import gzip
import kipoiseq
from kipoiseq import Interval
import pyfaidx
import pandas as pd
import numpy as np

# %%
transform_path = 'gs://dm-enformer/models/enformer.finetuned.SAD.robustscaler-PCA500-robustscaler.transform.pkl'
model_path = 'https://tfhub.dev/deepmind/enformer/1'

# %%
# Download targets from Basenji2 dataset 
# Cite: Kelley et al Cross-species regulatory sequence activity prediction. PLoS Comput. Biol. 16, e1008050 (2020).
targets_txt = 'https://raw.githubusercontent.com/calico/basenji/master/manuscripts/cross2020/targets_human.txt'
df_targets = pd.read_csv(targets_txt, sep='\t')
df_targets.head(3)
# Out:
#    index  genome   identifier  \
# 0      0       0  ENCFF833POA
# 1      1       0  ENCFF110QGM
# 2      2       0  ENCFF880MKD
#
#                                                 file  clip  scale sum_stat  \
# 0  /home/drk/tillage/datasets/human/dnase/encode/...    32      2     mean
# 1  /home/drk/tillage/datasets/human/dnase/encode/...    32      2     mean
# 2  /home/drk/tillage/datasets/human/dnase/encode/...    32      2     mean
#
#                                          description
# 0  DNASE:cerebellum male adult (27 years) and mal...
# 1  DNASE:frontal cortex male adult (27 years) and...
# 2                                      DNASE:chorion

# %%
targets_txt = 'https://raw.githubusercontent.com/calico/basenji/master/manuscripts/cross2020/targets_mouse.txt'
df_targets = pd.read_csv(targets_txt, sep='\t')
df_targets.head(3)
# Out:
#    index  genome   identifier  \
# 0   5313       1  ENCFF866ZTV
# 1   5314       1  ENCFF695LHM
# 2   5315       1  ENCFF079SPZ
#
#                                                 file  clip  scale sum_stat  \
# 0  /home/drk/tillage/datasets/mouse/dnase/encode/...    32      2     mean
# 1  /home/drk/tillage/datasets/mouse/dnase/encode/...    32      2     mean
# 2  /home/drk/tillage/datasets/mouse/dnase/encode/...    32      2     mean
#
#                                  description
# 0                        DNASE:B6D2F1/J 416B
# 1                        DNASE:BALB/cAnN A20
# 2  DNASE:C57BL/6 B cell male adult (8 weeks)

# %%
# @title `Enformer`, `EnformerScoreVariantsNormalized`, `EnformerScoreVariantsPCANormalized`,
SEQUENCE_LENGTH = 393216

class Enformer:

  def __init__(self, tfhub_url):
    self._model = hub.load(tfhub_url).model

  def predict_on_batch(self, inputs):
    predictions = self._model.predict_on_batch(inputs)
    return {k: v.numpy() for k, v in predictions.items()}

  @tf.function
  def contribution_input_grad(self, input_sequence,
                              target_mask, output_head='human'):
    input_sequence = input_sequence[tf.newaxis]

    target_mask_mass = tf.reduce_sum(target_mask)
    with tf.GradientTape() as tape:
      tape.watch(input_sequence)
      prediction = tf.reduce_sum(
          target_mask[tf.newaxis] *
          self._model.predict_on_batch(input_sequence)[output_head]) / target_mask_mass

    input_grad = tape.gradient(prediction, input_sequence) * input_sequence
    input_grad = tf.squeeze(input_grad, axis=0)
    return tf.reduce_sum(input_grad, axis=-1)


class EnformerScoreVariantsRaw:

  def __init__(self, tfhub_url, organism='human'):
    self._model = Enformer(tfhub_url)
    self._organism = organism
  
  def predict_on_batch(self, inputs):
    ref_prediction = self._model.predict_on_batch(inputs['ref'])[self._organism]
    alt_prediction = self._model.predict_on_batch(inputs['alt'])[self._organism]

    return alt_prediction.mean(axis=1) - ref_prediction.mean(axis=1)


class EnformerScoreVariantsNormalized:

  def __init__(self, tfhub_url, transform_pkl_path,
               organism='human'):
    assert organism == 'human', 'Transforms only compatible with organism=human'
    self._model = EnformerScoreVariantsRaw(tfhub_url, organism)
    with tf.io.gfile.GFile(transform_pkl_path, 'rb') as f:
      transform_pipeline = joblib.load(f)
    self._transform = transform_pipeline.steps[0][1]  # StandardScaler.
    
  def predict_on_batch(self, inputs):
    scores = self._model.predict_on_batch(inputs)
    return self._transform.transform(scores)


class EnformerScoreVariantsPCANormalized:

  def __init__(self, tfhub_url, transform_pkl_path,
               organism='human', num_top_features=500):
    self._model = EnformerScoreVariantsRaw(tfhub_url, organism)
    with tf.io.gfile.GFile(transform_pkl_path, 'rb') as f:
      self._transform = joblib.load(f)
    self._num_top_features = num_top_features
    
  def predict_on_batch(self, inputs):
    scores = self._model.predict_on_batch(inputs)
    return self._transform.transform(scores)[:, :self._num_top_features]


# TODO(avsec): Add feature description: Either PCX, or full names.

# %%
# @title `variant_centered_sequences`

class FastaStringExtractor:
    
    def __init__(self, fasta_file):
        self.fasta = pyfaidx.Fasta(fasta_file)
        self._chromosome_sizes = {k: len(v) for k, v in self.fasta.items()}

    def extract(self, interval: Interval, **kwargs) -> str:
        # Truncate interval if it extends beyond the chromosome lengths.
        chromosome_length = self._chromosome_sizes[interval.chrom]
        trimmed_interval = Interval(interval.chrom,
                                    max(interval.start, 0),
                                    min(interval.end, chromosome_length),
                                    )
        # pyfaidx wants a 1-based interval
        sequence = str(self.fasta.get_seq(trimmed_interval.chrom,
                                          trimmed_interval.start + 1,
                                          trimmed_interval.stop).seq).upper()
        # Fill truncated values with N's.
        pad_upstream = 'N' * max(-interval.start, 0)
        pad_downstream = 'N' * max(interval.end - chromosome_length, 0)
        return pad_upstream + sequence + pad_downstream

    def close(self):
        return self.fasta.close()


def variant_generator(vcf_file, gzipped=False):
  """Yields a kipoiseq.dataclasses.Variant for each row in VCF file."""
  def _open(file):
    return gzip.open(vcf_file, 'rt') if gzipped else open(vcf_file)
    
  with _open(vcf_file) as f:
    for line in f:
      if line.startswith('#'):
        continue
      chrom, pos, id, ref, alt_list = line.split('\t')[:5]
      # Split ALT alleles and return individual variants as output.
      for alt in alt_list.split(','):
        yield kipoiseq.dataclasses.Variant(chrom=chrom, pos=pos,
                                           ref=ref, alt=alt, id=id)


def one_hot_encode(sequence):
  return kipoiseq.transforms.functional.one_hot_dna(sequence).astype(np.float32)


def variant_centered_sequences(vcf_file, sequence_length, gzipped=False,
                               chr_prefix=''):
  seq_extractor = kipoiseq.extractors.VariantSeqExtractor(
    reference_sequence=FastaStringExtractor(fasta_file))

  for variant in variant_generator(vcf_file, gzipped=gzipped):
    interval = Interval(chr_prefix + variant.chrom,
                        variant.pos, variant.pos)
    interval = interval.resize(sequence_length)
    center = interval.center() - interval.start

    reference = seq_extractor.extract(interval, [], anchor=center)
    alternate = seq_extractor.extract(interval, [variant], anchor=center)

    yield {'inputs': {'ref': one_hot_encode(reference),
                      'alt': one_hot_encode(alternate)},
           'metadata': {'chrom': chr_prefix + variant.chrom,
                        'pos': variant.pos,
                        'id': variant.id,
                        'ref': variant.ref,
                        'alt': variant.alt}}

# %%
fasta_file = '/data/pfenninggroup/machineLearningForComputationalBiology/regElEvoGrant/200MammalsFastas/susScr3.fa'
fasta_extractor = FastaStringExtractor(fasta_file)

# @title Make predictions for an genomic example interval
target_interval = kipoiseq.Interval('chr1', 55_140_272, 55_533_488)

sequence_one_hot = one_hot_encode(fasta_extractor.extract(target_interval.resize(SEQUENCE_LENGTH)))

# %%
model = Enformer(model_path)

predictions = model.predict_on_batch(sequence_one_hot[np.newaxis])['human'][0]
# Out:
# 2026-01-06 18:19:48.173717: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-01-06 18:19:48.174291: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:3b:00.0 name: NVIDIA RTX A6000 computeCapability: 8.6
# coreClock: 1.8GHz coreCount: 84 deviceMemorySize: 47.54GiB deviceMemoryBandwidth: 715.34GiB/s
# 2026-01-06 18:19:48.174540: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2026-01-06 18:19:48.174574: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2026-01-06 18:19:48.892229: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2026-01-06 18:19:48.892260: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2026-01-06 18:19:48.892265: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2026-01-06 18:19:48.892754: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 896 MB memory) -> physical GPU (device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:3b:00.0, compute capability: 8.6)
# 2026-01-06 18:20:00.610197: W tensorflow/core/common_runtime/bfc_allocator.cc:456] Allocator (GPU_0_bfc) ran out of memory trying to allocate 9.00MiB (rounded to 9437184)requested by op Identity
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# 2026-01-06 18:20:00.610304: I tensorflow/core/common_runtime/bfc_allocator.cc:991] BFCAllocator dump for GPU_0_bfc
# 2026-01-06 18:20:00.610331: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (256): 	Total Chunks: 28, Chunks in use: 28. 7.0KiB allocated for chunks. 7.0KiB in use in bin. 224B client-requested in use in bin.
# 2026-01-06 18:20:00.610346: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (512): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2026-01-06 18:20:00.610360: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (1024): 	Total Chunks: 1, Chunks in use: 1. 1.2KiB allocated for chunks. 1.2KiB in use in bin. 1.0KiB client-requested in use in bin.
# 2026-01-06 18:20:00.610378: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 model = Enformer(model_path)
#       3 predictions = model.predict_on_batch(sequence_one_hot[np.newaxis])['human'][0]
#
# Cell In[7], line 7, in Enformer.__init__(self, tfhub_url)
#       6 def __init__(self, tfhub_url):
# ----> 7   self._model = hub.load(tfhub_url).model
#
# File ~/miniconda3/envs/enformer_env/lib/python3.9/site-packages/tensorflow_hub/module_v2.py:106, in load(handle, tags, options)
#     103   obj = tf.compat.v1.saved_model.load_v2(
#     104       module_path, tags=tags, options=options)
#     105 else:
# --> 106   obj = tf.compat.v1.saved_model.load_v2(module_path, tags=tags)
#     107 obj._is_hub_module_v1 = is_hub_module_v1  # pylint: disable=protected-access
#     108 return obj
#
# File ~/miniconda3/envs/enformer_env/lib/python3.9/site-packages/tensorflow/python/saved_model/load.py:869, in load(export_dir, tags, options)
#     778 @tf_export("saved_model.load", v1=["saved_model.load_v2"])
#     779 def load(export_dir, tags=None, options=None):
#     780   """Load a SavedModel from `export_dir`.
#     781
#     782   Signatures associated with the SavedModel are available as functions:
#    (...)
#     867     ValueError: If `tags` don't match a MetaGraph in the SavedModel.
#     868   """
# --> 869   return load_internal(export_dir, tags, options)["root"]
#
# File ~/miniconda3/envs/enformer_env/lib/python3.9/site-packages/tensorflow/python/saved_model/load.py:905, in load_internal(export_dir, tags, options, loader_cls, filters)
#     903 with ops.init_scope():
#     904   try:
# --> 905     loader = loader_cls(object_graph_proto, saved_model_proto, export_dir,
#     906                         ckpt_options, filters)
#     907   except errors.NotFoundError as err:
#     908     raise FileNotFoundError(
#     909         str(err) + "\n If trying to load on a different device from the "
#     910         "computational device, consider using setting the "
#     911         "`experimental_io_device` option on tf.saved_model.LoadOptions "
#     912         "to the io_device such as '/job:localhost'."
#     913     )
#
# File ~/miniconda3/envs/enformer_env/lib/python3.9/site-packages/tensorflow/python/saved_model/load.py:163, in Loader.__init__(self, object_graph_proto, saved_model_proto, export_dir, ckpt_options, filters)
#     160   self._concrete_functions[name] = _WrapperFunction(concrete_function)
#     162 self._load_all()
# --> 163 self._restore_checkpoint()
#     165 for node in self._nodes:
#     166   if isinstance(node, tracking.CapturableResource):
#
# File ~/miniconda3/envs/enformer_env/lib/python3.9/site-packages/tensorflow/python/saved_model/load.py:489, in Loader._restore_checkpoint(self)
#     486   load_status = saver.restore(variables_path,
#     487                               self._checkpoint_options).expect_partial()
#     488 else:
# --> 489   load_status = saver.restore(variables_path, self._checkpoint_options)
#     490 load_status.assert_existing_objects_matched()
#     491 checkpoint = load_status._checkpoint
#
# File ~/miniconda3/envs/enformer_env/lib/python3.9/site-packages/tensorflow/python/training/tracking/util.py:1338, in TrackableSaver.restore(self, save_path, options)
#    1330 object_graph_proto.ParseFromString(object_graph_string)
#    1331 checkpoint = _CheckpointRestoreCoordinator(
#    1332     object_graph_proto=object_graph_proto,
#    1333     save_path=save_path,
#    (...)
#    1336     graph_view=self._graph_view,
#    1337     options=options)
# -> 1338 base.CheckpointPosition(
#    1339     checkpoint=checkpoint, proto_id=0).restore(self._graph_view.root)
#    1341 # Attached dependencies are not attached to the root, so should be restored
#    1342 # separately.
#    1343 if self._graph_view.attached_dependencies:
#
# File ~/miniconda3/envs/enformer_env/lib/python3.9/site-packages/tensorflow/python/training/tracking/base.py:258, in CheckpointPosition.restore(self, trackable)
#     254 with ops.init_scope():
#     255   if self.bind_object(trackable):
#     256     # This object's correspondence with a checkpointed object is new, so
#     257     # process deferred restorations for it and its dependencies.
# --> 258     restore_ops = trackable._restore_from_checkpoint_position(self)  # pylint: disable=protected-access
#     259     if restore_ops:
#     260       self._checkpoint.new_restore_ops(restore_ops)
#
# File ~/miniconda3/envs/enformer_env/lib/python3.9/site-packages/tensorflow/python/training/tracking/base.py:977, in Trackable._restore_from_checkpoint_position(self, checkpoint_position)
#     974   tensor_saveables.update(new_tensor_saveables)
#     975   python_saveables.extend(new_python_saveables)
#     976 restore_ops.extend(
# --> 977     current_position.checkpoint.restore_saveables(
#     978         tensor_saveables, python_saveables))
#     979 return restore_ops
#
# File ~/miniconda3/envs/enformer_env/lib/python3.9/site-packages/tensorflow/python/training/tracking/util.py:308, in _CheckpointRestoreCoordinator.restore_saveables(self, tensor_saveables, python_saveables)
#     304 if set(tensor_saveables.keys()) != validated_names:
#     305   raise AssertionError(
#     306       ("Saveable keys changed when validating. Got back %s, was "
#     307        "expecting %s") % (tensor_saveables.keys(), validated_names))
# --> 308 new_restore_ops = functional_saver.MultiDeviceSaver(
#     309     validated_saveables).restore(self.save_path_tensor, self.options)
#     310 if not context.executing_eagerly():
#     311   for name, restore_op in sorted(new_restore_ops.items()):
#
# File ~/miniconda3/envs/enformer_env/lib/python3.9/site-packages/tensorflow/python/training/saving/functional_saver.py:339, in MultiDeviceSaver.restore(self, file_prefix, options)
#     337   restore_ops = tf_function_restore()
#     338 else:
# --> 339   restore_ops = restore_fn()
#     341 for callback in self._after_restore_callbacks:
#     342   callback()
#
# File ~/miniconda3/envs/enformer_env/lib/python3.9/site-packages/tensorflow/python/training/saving/functional_saver.py:323, in MultiDeviceSaver.restore.<locals>.restore_fn()
#     321 for device, saver in sorted(self._single_device_savers.items()):
#     322   with ops.device(device):
# --> 323     restore_ops.update(saver.restore(file_prefix, options))
#     325 return restore_ops
#
# File ~/miniconda3/envs/enformer_env/lib/python3.9/site-packages/tensorflow/python/training/saving/functional_saver.py:115, in _SingleDeviceSaver.restore(self, file_prefix, options)
#     112 restore_ops = {}
#     113 for saveable, restored_tensors in zip(self._saveable_objects,
#     114                                       structured_restored_tensors):
# --> 115   restore_ops[saveable.name] = saveable.restore(
#     116       restored_tensors, restored_shapes=None)
#     117 return restore_ops
#
# File ~/miniconda3/envs/enformer_env/lib/python3.9/site-packages/tensorflow/python/training/saving/saveable_object_util.py:130, in ResourceVariableSaveable.restore(self, restored_tensors, restored_shapes)
#     128 # Copy the restored tensor to the variable's device.
#     129 with ops.device(self._var_device):
# --> 130   restored_tensor = array_ops.identity(restored_tensor)
#     131   return resource_variable_ops.shape_safe_assign_variable_handle(
#     132       self.handle_op, self._var_shape, restored_tensor)
#
# File ~/miniconda3/envs/enformer_env/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:206, in add_dispatch_support.<locals>.wrapper(*args, **kwargs)
#     204 """Call target, and fall back on dispatchers if there is a TypeError."""
#     205 try:
# --> 206   return target(*args, **kwargs)
#     207 except (TypeError, ValueError):
#     208   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#     209   # TypeError, when given unexpected types.  So we need to catch both.
#     210   result = dispatch(wrapper, args, kwargs)
#
# File ~/miniconda3/envs/enformer_env/lib/python3.9/site-packages/tensorflow/python/ops/array_ops.py:288, in identity(input, name)
#     284 if context.executing_eagerly() and not hasattr(input, "graph"):
#     285   # Make sure we get an input with handle data attached from resource
#     286   # variables. Variables have correct handle data when graph building.
#     287   input = ops.convert_to_tensor(input)
# --> 288 ret = gen_array_ops.identity(input, name=name)
#     289 # Propagate handle data for happier shape inference for resource variables.
#     290 if hasattr(input, "_handle_data"):
#
# File ~/miniconda3/envs/enformer_env/lib/python3.9/site-packages/tensorflow/python/ops/gen_array_ops.py:3953, in identity(input, name)
#    3951   return _result
#    3952 except _core._NotOkStatusException as e:
# -> 3953   _ops.raise_from_not_ok_status(e, name)
#    3954 except _core._FallbackException:
#    3955   pass
#
# File ~/miniconda3/envs/enformer_env/lib/python3.9/site-packages/tensorflow/python/framework/ops.py:6897, in raise_from_not_ok_status(e, name)
#    6895 message = e.message + (" name: " + name if name is not None else "")
#    6896 # pylint: disable=protected-access
# -> 6897 six.raise_from(core._status_to_exception(e.code, message), None)
#
# File <string>:3, in raise_from(value, from_value)
#
# InternalError: Failed copying input tensor from /job:localhost/replica:0/task:0/device:CPU:0 to /job:localhost/replica:0/task:0/device:GPU:0 in order to run Identity: Dst tensor is not initialized. [Op:Identity]
