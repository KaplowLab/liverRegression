# %%
import pandas as pd
from scipy.stats import rankdata
import sys
import numpy as np


def quantile_normalize(values):
    """Quantile normalization of a vector."""
    sorted_idx = np.argsort(values)
    sorted_values = np.sort(values)

    print(sorted_idx)
    print(sorted_values)
    # quantiles = np.mean(sorted_values)
    # return np.array([quantiles for i in range(len(values))])[sorted_idx.argsort()]

A = [5, 4, 3]
B = [2, 1, 4]
C = [3, 4, 6]
D = [4, 2, 8]

quantile_normalize(A)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 20
#      17 C = [3, 4, 6]
#      18 D = [4, 2, 8]
# ---> 20 quantile_normalize(A)
#
# Cell In[4], line 10, in quantile_normalize(values)
#       7 """Quantile normalization of a vector."""
#       8 sorted_values = np.sort(values)
# ---> 10 print(sorted_idx)
#      11 print(sorted_values)
#
# NameError: name 'sorted_idx' is not defined
